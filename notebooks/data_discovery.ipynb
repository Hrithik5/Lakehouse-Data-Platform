# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("ETL Pipeline")
    .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/07 13:07:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df_customers = spark.read.csv("../data/raw/customers_dataset.csv", header=True, inferSchema=True)
df_geolocation = spark.read.csv("../data/raw/geolocation_dataset.csv", header=True, inferSchema=True)
df_order_items = spark.read.csv("../data/raw/order_items_dataset.csv", header=True, inferSchema=True)
df_order_payments = spark.read.csv("../data/raw/order_payments_dataset.csv", header=True, inferSchema=True)
df_order_reviews = spark.read.csv("../data/raw/order_reviews_dataset.csv", header=True, inferSchema=True)
df_orders = spark.read.csv("../data/raw/orders_dataset.csv", header=True, inferSchema=True)
df_product_category = spark.read.csv("../data/raw/product_category_name_translation.csv", header=True, inferSchema=True)
df_products = spark.read.csv("../data/raw/products_dataset.csv", header=True, inferSchema=True)
df_sellers = spark.read.csv("../data/raw/sellers_dataset.csv", header=True, inferSchema=True)

# %%
from pyspark.sql.functions import col, count, coalesce, lit
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)

df_order_reviews.select(col("order_id")).limit(20).toPandas()
